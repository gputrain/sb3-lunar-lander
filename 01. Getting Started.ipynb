# %%
import gymnasium as gym

# %% [markdown]
# #### 1. Setup the environment with render mode to observe

# %%
env =gym.make('LunarLander-v2',render_mode='human')

# %% [markdown]
# #### 2. Reset the environment

# %%
env.reset()
# Out:
# (array([ 0.00406256,  1.403513  ,  0.41147438, -0.32920933, -0.00470068,
#         -0.09320503,  0.        ,  0.        ], dtype=float32),
#  {})

# %% [markdown]
# #### 3. Sample Actions, Observation Space and Sample Observation Space

# %%
print ('sample action', env.action_space.sample())
print ('observation space shape',env.observation_space.shape)
print ('sample observation',env.observation_space.sample)
# Out:
# sample action 1
# observation space shape (8,)
# sample observation <bound method Box.sample of Box([-1.5       -1.5       -5.        -5.        -3.1415927 -5.
#  -0.        -0.       ], [1.5       1.5       5.        5.        3.1415927 5.        1.
#  1.       ], (8,), float32)>

# %% [markdown]
# #### 4. Close the env.

# %%
env.close()

# %% [markdown]
# #### 5. Final reward is -100 at the end of episode. With random action observe not -100 on ~141th epoch

# %%
reward = -100
episode = 1
while reward ==-100:
    env =gym.make('LunarLander-v2',render_mode='human')
    env.reset()
    for step in range (200):
        env.render()
        obs,reward,done, info, _ =env.step(env.action_space.sample())
        
    env.close()
    episode +=1 
    print (episode,reward)

# %% [markdown]
# ##### Key principles to consider in a game

# %% [markdown]
# # Gains in RL algorithms (ranked)
# - Altering algorithms
# - Altering reward space parameters
# - Hyper parameter tuning for the algorithm

# %% [markdown]
# ####| https://stable-baselines3.readthedocs.io/en/master/guide/algos.html

# %% [markdown]
# #### 6. Train via A2C

# %%
from stable_baselines3 import A2C

# %%
env =gym.make('LunarLander-v2')

# %%
model = A2C('MlpPolicy', env, verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=100000)
episodes=10
for ep in range (episodes):
    obs = env.reset()
    done = False
    while not done:
        env.render()
        obs,reward,done, info, _ =env.step(env.action_space.sample())
# Out:
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 87        |
# |    ep_rew_mean        | -281      |
# | time/                 |           |
# |    fps                | 229       |
# |    iterations         | 100       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -1.37     |
# |    explained_variance | -8.79e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -23.9     |
# |    value_loss         | 286       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 88.9     |
# |    ep_rew_mean        | -292     |
# | time/                 |          |
# |    fps                | 334      |
# |    iterations         | 200      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.13    |
# |    explained_variance | -0.0153  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -2.84    |
# |    value_loss         | 17.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 91.1     |
# |    ep_rew_mean        | -303     |
# | time/                 |          |
# |    fps                | 394      |
# |    iterations         | 300      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | -0.00565 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -2.64    |
# |    value_loss         | 3.83     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93.8     |
# |    ep_rew_mean        | -278     |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 400      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.14    |
# |    explained_variance | -0.00159 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -2.56    |
# |    value_loss         | 5.74     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 106       |
# |    ep_rew_mean        | -292      |
# | time/                 |           |
# |    fps                | 457       |
# |    iterations         | 500       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -1.03     |
# |    explained_variance | -0.000432 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -5.29     |
# |    value_loss         | 16        |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 114      |
# |    ep_rew_mean        | -278     |
# | time/                 |          |
# |    fps                | 471      |
# |    iterations         | 600      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.741   |
# |    explained_variance | -0.00125 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.0534  |
# |    value_loss         | 1.68     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 121      |
# |    ep_rew_mean        | -280     |
# | time/                 |          |
# |    fps                | 479      |
# |    iterations         | 700      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.926   |
# |    explained_variance | -0.00503 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 1.62     |
# |    value_loss         | 23.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 131      |
# |    ep_rew_mean        | -276     |
# | time/                 |          |
# |    fps                | 486      |
# |    iterations         | 800      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.905   |
# |    explained_variance | 0.000236 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -2.28    |
# |    value_loss         | 11.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 133      |
# |    ep_rew_mean        | -271     |
# | time/                 |          |
# |    fps                | 490      |
# |    iterations         | 900      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.859   |
# |    explained_variance | 6.71e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -4.09    |
# |    value_loss         | 15.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 142      |
# |    ep_rew_mean        | -255     |
# | time/                 |          |
# |    fps                | 493      |
# |    iterations         | 1000     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.855   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 4.04     |
# |    value_loss         | 34.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 142      |
# |    ep_rew_mean        | -255     |
# | time/                 |          |
# |    fps                | 495      |
# |    iterations         | 1100     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -1.35    |
# |    explained_variance | -0.0871  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -1.56    |
# |    value_loss         | 1.68     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 166      |
# |    ep_rew_mean        | -244     |
# | time/                 |          |
# |    fps                | 496      |
# |    iterations         | 1200     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | 0.0802   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.857   |
# |    value_loss         | 0.725    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 170      |
# |    ep_rew_mean        | -240     |
# | time/                 |          |
# |    fps                | 497      |
# |    iterations         | 1300     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.773   |
# |    explained_variance | 0.0154   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.222    |
# |    value_loss         | 1.02     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 173      |
# |    ep_rew_mean        | -230     |
# | time/                 |          |
# |    fps                | 498      |
# |    iterations         | 1400     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.704   |
# |    explained_variance | -0.00689 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 9.54     |
# |    value_loss         | 51.9     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 177       |
# |    ep_rew_mean        | -227      |
# | time/                 |           |
# |    fps                | 498       |
# |    iterations         | 1500      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.646    |
# |    explained_variance | -0.000791 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 0.142     |
# |    value_loss         | 0.94      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 179      |
# |    ep_rew_mean        | -225     |
# | time/                 |          |
# |    fps                | 498      |
# |    iterations         | 1600     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.648   |
# |    explained_variance | 0.0708   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -3.91    |
# |    value_loss         | 24.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -223     |
# | time/                 |          |
# |    fps                | 499      |
# |    iterations         | 1700     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | -0.00406 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 8.14     |
# |    value_loss         | 262      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 186      |
# |    ep_rew_mean        | -223     |
# | time/                 |          |
# |    fps                | 501      |
# |    iterations         | 1800     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.759   |
# |    explained_variance | -0.0164  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 5.16     |
# |    value_loss         | 81.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 188      |
# |    ep_rew_mean        | -222     |
# | time/                 |          |
# |    fps                | 500      |
# |    iterations         | 1900     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.737   |
# |    explained_variance | 0.000406 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -5.06    |
# |    value_loss         | 78.7     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 190       |
# |    ep_rew_mean        | -215      |
# | time/                 |           |
# |    fps                | 504       |
# |    iterations         | 2000      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.911    |
# |    explained_variance | -0.000308 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 3.31      |
# |    value_loss         | 55.5      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 194       |
# |    ep_rew_mean        | -212      |
# | time/                 |           |
# |    fps                | 508       |
# |    iterations         | 2100      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.836    |
# |    explained_variance | -0.000968 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -0.953    |
# |    value_loss         | 0.555     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 195      |
# |    ep_rew_mean        | -213     |
# | time/                 |          |
# |    fps                | 512      |
# |    iterations         | 2200     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.72    |
# |    explained_variance | 0.0123   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -6.1     |
# |    value_loss         | 95.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 199      |
# |    ep_rew_mean        | -207     |
# | time/                 |          |
# |    fps                | 514      |
# |    iterations         | 2300     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.68    |
# |    explained_variance | 0.00339  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 1.52     |
# |    value_loss         | 7.03     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 201      |
# |    ep_rew_mean        | -207     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 2400     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.684   |
# |    explained_variance | 0.000468 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 3.99     |
# |    value_loss         | 55.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 202      |
# |    ep_rew_mean        | -204     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 2500     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.451   |
# |    explained_variance | -0.00257 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -3.16    |
# |    value_loss         | 79.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 202      |
# |    ep_rew_mean        | -205     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 2600     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.717   |
# |    explained_variance | -0.118   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.167    |
# |    value_loss         | 0.174    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 207      |
# |    ep_rew_mean        | -198     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 2700     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -1.14    |
# |    explained_variance | 0.000225 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 2.58     |
# |    value_loss         | 4.88     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | -199     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 2800     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.0545  |
# |    explained_variance | -0.706   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.779   |
# |    value_loss         | 6.76e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 210      |
# |    ep_rew_mean        | -193     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 2900     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.148   |
# |    explained_variance | 0.0166   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -0.0502  |
# |    value_loss         | 3.75     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 210      |
# |    ep_rew_mean        | -190     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 3000     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.58    |
# |    explained_variance | -0.0102  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 2.84     |
# |    value_loss         | 28.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 212      |
# |    ep_rew_mean        | -188     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 3100     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.3     |
# |    explained_variance | -0.592   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.392   |
# |    value_loss         | 3.74e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 213      |
# |    ep_rew_mean        | -184     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 3200     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.521   |
# |    explained_variance | -0.0975  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 2.91     |
# |    value_loss         | 187      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 213      |
# |    ep_rew_mean        | -185     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 3300     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.459   |
# |    explained_variance | 0.00625  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 8.36     |
# |    value_loss         | 275      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 213      |
# |    ep_rew_mean        | -180     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 3400     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.652   |
# |    explained_variance | -0.109   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 2.2      |
# |    value_loss         | 10.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 214      |
# |    ep_rew_mean        | -176     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 3500     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.373   |
# |    explained_variance | -0.0597  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -0.955   |
# |    value_loss         | 53.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 214      |
# |    ep_rew_mean        | -177     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 3600     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.586   |
# |    explained_variance | -0.142   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 1.24     |
# |    value_loss         | 7.41     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 215      |
# |    ep_rew_mean        | -176     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 3700     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.216   |
# |    explained_variance | 0.147    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.0679   |
# |    value_loss         | 2.16     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 215      |
# |    ep_rew_mean        | -174     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 3800     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.722   |
# |    explained_variance | 0.0243   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -9.83    |
# |    value_loss         | 73       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 214      |
# |    ep_rew_mean        | -175     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 3900     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.492   |
# |    explained_variance | -0.347   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 1.46     |
# |    value_loss         | 6.03     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 212      |
# |    ep_rew_mean        | -173     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 4000     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0172  |
# |    explained_variance | -0.548   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.00125 |
# |    value_loss         | 11.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 212      |
# |    ep_rew_mean        | -170     |
# | time/                 |          |
# |    fps                | 514      |
# |    iterations         | 4100     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.495   |
# |    explained_variance | 0.127    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -1.2     |
# |    value_loss         | 59.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 212      |
# |    ep_rew_mean        | -171     |
# | time/                 |          |
# |    fps                | 514      |
# |    iterations         | 4200     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.238   |
# |    explained_variance | -0.52    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 1.54     |
# |    value_loss         | 448      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 214      |
# |    ep_rew_mean        | -170     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 4300     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.123   |
# |    explained_variance | -0.0308  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -2.75    |
# |    value_loss         | 9.61     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 216      |
# |    ep_rew_mean        | -167     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 4400     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.344   |
# |    explained_variance | -0.117   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.519   |
# |    value_loss         | 25.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 220      |
# |    ep_rew_mean        | -165     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 4500     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -0.645   |
# |    explained_variance | -0.0577  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 5.42     |
# |    value_loss         | 61.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 223      |
# |    ep_rew_mean        | -164     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 4600     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -0.452   |
# |    explained_variance | -0.669   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -2.89    |
# |    value_loss         | 71.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | -158     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 4700     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -0.618   |
# |    explained_variance | -3.05    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 2.35     |
# |    value_loss         | 21.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 228      |
# |    ep_rew_mean        | -154     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 4800     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.441   |
# |    explained_variance | -0.0398  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 7.37     |
# |    value_loss         | 154      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 231      |
# |    ep_rew_mean        | -147     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 4900     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -0.584   |
# |    explained_variance | 0.0329   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -4.93    |
# |    value_loss         | 144      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 234      |
# |    ep_rew_mean        | -146     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 5000     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -0.614   |
# |    explained_variance | 0.504    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.92    |
# |    value_loss         | 12.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 236      |
# |    ep_rew_mean        | -140     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 5100     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -0.49    |
# |    explained_variance | -3.51    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | 2.56     |
# |    value_loss         | 36       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 235      |
# |    ep_rew_mean        | -136     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 5200     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.286   |
# |    explained_variance | 0.0104   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.0999  |
# |    value_loss         | 5.6      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 236      |
# |    ep_rew_mean        | -128     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 5300     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -0.534   |
# |    explained_variance | -0.219   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 7.5      |
# |    value_loss         | 141      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 235      |
# |    ep_rew_mean        | -125     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 5400     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -0.658   |
# |    explained_variance | -0.68    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | 3.58     |
# |    value_loss         | 31.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 236      |
# |    ep_rew_mean        | -122     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 5500     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.663   |
# |    explained_variance | -0.773   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | -0.233   |
# |    value_loss         | 1.44     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 233      |
# |    ep_rew_mean        | -121     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 5600     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.526   |
# |    explained_variance | -0.271   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 1.92     |
# |    value_loss         | 19.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 235      |
# |    ep_rew_mean        | -121     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 5700     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -0.612   |
# |    explained_variance | 0.396    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.0243   |
# |    value_loss         | 1.7      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 226      |
# |    ep_rew_mean        | -123     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 5800     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.664   |
# |    explained_variance | -0.0609  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 2.82     |
# |    value_loss         | 26.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 226      |
# |    ep_rew_mean        | -124     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 5900     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -0.572   |
# |    explained_variance | 0.00366  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 13.3     |
# |    value_loss         | 926      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | -122     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 6000     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.587   |
# |    explained_variance | -10.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.742    |
# |    value_loss         | 9.04     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 226      |
# |    ep_rew_mean        | -121     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 6100     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.491   |
# |    explained_variance | 0.743    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 1.03     |
# |    value_loss         | 28.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 227      |
# |    ep_rew_mean        | -114     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 6200     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -0.253   |
# |    explained_variance | -0.445   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.157   |
# |    value_loss         | 9.42     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | -112     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 6300     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -0.446   |
# |    explained_variance | 0.168    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.825   |
# |    value_loss         | 31.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | -107     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 6400     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.641   |
# |    explained_variance | -0.0149  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 4.45     |
# |    value_loss         | 53.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | -108     |
# | time/                 |          |
# |    fps                | 516      |
# |    iterations         | 6500     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.394   |
# |    explained_variance | -0.9     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -4.33    |
# |    value_loss         | 17.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | -107     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 6600     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -0.67    |
# |    explained_variance | -0.101   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.191   |
# |    value_loss         | 0.531    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 223      |
# |    ep_rew_mean        | -109     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 6700     |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.558   |
# |    explained_variance | -0.0263  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 5.88     |
# |    value_loss         | 90.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 221      |
# |    ep_rew_mean        | -106     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 6800     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.0401  |
# |    explained_variance | 0.444    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | 0.0271   |
# |    value_loss         | 32.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 222      |
# |    ep_rew_mean        | -103     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 6900     |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.484   |
# |    explained_variance | -0.0278  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 2.27     |
# |    value_loss         | 16.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 219      |
# |    ep_rew_mean        | -105     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 7000     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -0.955   |
# |    explained_variance | -0.131   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | -1.28    |
# |    value_loss         | 7.56     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 220      |
# |    ep_rew_mean        | -104     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 7100     |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -0.627   |
# |    explained_variance | 0.978    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | 0.129    |
# |    value_loss         | 0.234    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 219      |
# |    ep_rew_mean        | -103     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 7200     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.979   |
# |    explained_variance | -0.221   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | -3.14    |
# |    value_loss         | 75.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 220      |
# |    ep_rew_mean        | -106     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 7300     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -0.376   |
# |    explained_variance | 0.613    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | -4.91    |
# |    value_loss         | 46.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 220      |
# |    ep_rew_mean        | -105     |
# | time/                 |          |
# |    fps                | 514      |
# |    iterations         | 7400     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -0.531   |
# |    explained_variance | 0.0262   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | 3.97     |
# |    value_loss         | 186      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 219      |
# |    ep_rew_mean        | -106     |
# | time/                 |          |
# |    fps                | 514      |
# |    iterations         | 7500     |
# |    time_elapsed       | 72       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -0.684   |
# |    explained_variance | 0.593    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | 2.14     |
# |    value_loss         | 22.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 220      |
# |    ep_rew_mean        | -108     |
# | time/                 |          |
# |    fps                | 514      |
# |    iterations         | 7600     |
# |    time_elapsed       | 73       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.163   |
# |    explained_variance | -1.99    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | -2.48    |
# |    value_loss         | 1.15e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 220      |
# ...
# | rollout/              |          |
# |    ep_len_mean        | 333      |
# |    ep_rew_mean        | -17.2    |
# | time/                 |          |
# |    fps                | 507      |
# |    iterations         | 17600    |
# |    time_elapsed       | 173      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -0.00613 |
# |    explained_variance | 0.581    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17599    |
# |    policy_loss        | 0.00269  |
# |    value_loss         | 12.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 333      |
# |    ep_rew_mean        | -17.5    |
# | time/                 |          |
# |    fps                | 507      |
# |    iterations         | 17700    |
# |    time_elapsed       | 174      |
# |    total_timesteps    | 88500    |
# | train/                |          |
# |    entropy_loss       | -0.557   |
# |    explained_variance | 0.796    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17699    |
# |    policy_loss        | -1.98    |
# |    value_loss         | 49       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 335      |
# |    ep_rew_mean        | -14.2    |
# | time/                 |          |
# |    fps                | 507      |
# |    iterations         | 17800    |
# |    time_elapsed       | 175      |
# |    total_timesteps    | 89000    |
# | train/                |          |
# |    entropy_loss       | -0.535   |
# |    explained_variance | 0.00909  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17799    |
# |    policy_loss        | 2.95     |
# |    value_loss         | 77.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 337      |
# |    ep_rew_mean        | -11.7    |
# | time/                 |          |
# |    fps                | 507      |
# |    iterations         | 17900    |
# |    time_elapsed       | 176      |
# |    total_timesteps    | 89500    |
# | train/                |          |
# |    entropy_loss       | -0.619   |
# |    explained_variance | -1.48    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17899    |
# |    policy_loss        | 1.34     |
# |    value_loss         | 12.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 341      |
# |    ep_rew_mean        | -11.9    |
# | time/                 |          |
# |    fps                | 507      |
# |    iterations         | 18000    |
# |    time_elapsed       | 177      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -0.477   |
# |    explained_variance | 0.979    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17999    |
# |    policy_loss        | -0.184   |
# |    value_loss         | 0.825    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 339      |
# |    ep_rew_mean        | -9.51    |
# | time/                 |          |
# |    fps                | 507      |
# |    iterations         | 18100    |
# |    time_elapsed       | 178      |
# |    total_timesteps    | 90500    |
# | train/                |          |
# |    entropy_loss       | -0.555   |
# |    explained_variance | 0.841    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18099    |
# |    policy_loss        | -0.276   |
# |    value_loss         | 1.73     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 338      |
# |    ep_rew_mean        | -12      |
# | time/                 |          |
# |    fps                | 507      |
# |    iterations         | 18200    |
# |    time_elapsed       | 179      |
# |    total_timesteps    | 91000    |
# | train/                |          |
# |    entropy_loss       | -0.523   |
# |    explained_variance | 0.102    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18199    |
# |    policy_loss        | 1.16     |
# |    value_loss         | 11.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 339      |
# |    ep_rew_mean        | -12.5    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 18300    |
# |    time_elapsed       | 180      |
# |    total_timesteps    | 91500    |
# | train/                |          |
# |    entropy_loss       | -0.0926  |
# |    explained_variance | -0.842   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18299    |
# |    policy_loss        | 0.0437   |
# |    value_loss         | 12.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 342      |
# |    ep_rew_mean        | -6.07    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 18400    |
# |    time_elapsed       | 181      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -0.401   |
# |    explained_variance | 0.0655   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18399    |
# |    policy_loss        | 3.63     |
# |    value_loss         | 45.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 343      |
# |    ep_rew_mean        | -7.38    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 18500    |
# |    time_elapsed       | 182      |
# |    total_timesteps    | 92500    |
# | train/                |          |
# |    entropy_loss       | -0.506   |
# |    explained_variance | 0.625    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18499    |
# |    policy_loss        | -1.83    |
# |    value_loss         | 13.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 344      |
# |    ep_rew_mean        | -12.6    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 18600    |
# |    time_elapsed       | 183      |
# |    total_timesteps    | 93000    |
# | train/                |          |
# |    entropy_loss       | -0.375   |
# |    explained_variance | 0.374    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18599    |
# |    policy_loss        | 3.5      |
# |    value_loss         | 13.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 346      |
# |    ep_rew_mean        | -12.9    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 18700    |
# |    time_elapsed       | 184      |
# |    total_timesteps    | 93500    |
# | train/                |          |
# |    entropy_loss       | -0.549   |
# |    explained_variance | 0.941    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18699    |
# |    policy_loss        | -0.0109  |
# |    value_loss         | 0.427    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 347      |
# |    ep_rew_mean        | -10.2    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 18800    |
# |    time_elapsed       | 185      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -0.25    |
# |    explained_variance | -0.47    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18799    |
# |    policy_loss        | -3.16    |
# |    value_loss         | 63.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 347      |
# |    ep_rew_mean        | -10.2    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 18900    |
# |    time_elapsed       | 186      |
# |    total_timesteps    | 94500    |
# | train/                |          |
# |    entropy_loss       | -0.249   |
# |    explained_variance | -1.64    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18899    |
# |    policy_loss        | 0.0756   |
# |    value_loss         | 0.00311  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 348      |
# |    ep_rew_mean        | -7.44    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 19000    |
# |    time_elapsed       | 187      |
# |    total_timesteps    | 95000    |
# | train/                |          |
# |    entropy_loss       | -0.783   |
# |    explained_variance | 0.16     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18999    |
# |    policy_loss        | -0.962   |
# |    value_loss         | 5.72     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 348      |
# |    ep_rew_mean        | -7.44    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 19100    |
# |    time_elapsed       | 188      |
# |    total_timesteps    | 95500    |
# | train/                |          |
# |    entropy_loss       | -0.452   |
# |    explained_variance | 0.878    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19099    |
# |    policy_loss        | 1.16     |
# |    value_loss         | 30       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 353      |
# |    ep_rew_mean        | -5.88    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 19200    |
# |    time_elapsed       | 189      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -0.375   |
# |    explained_variance | 0.463    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19199    |
# |    policy_loss        | 1.55     |
# |    value_loss         | 4.33     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 353      |
# |    ep_rew_mean        | -5.88    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 19300    |
# |    time_elapsed       | 190      |
# |    total_timesteps    | 96500    |
# | train/                |          |
# |    entropy_loss       | -0.803   |
# |    explained_variance | -1.26    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19299    |
# |    policy_loss        | -1.41    |
# |    value_loss         | 1.16     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 359      |
# |    ep_rew_mean        | -7.27    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 19400    |
# |    time_elapsed       | 191      |
# |    total_timesteps    | 97000    |
# | train/                |          |
# |    entropy_loss       | -0.413   |
# |    explained_variance | -0.46    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19399    |
# |    policy_loss        | -0.598   |
# |    value_loss         | 13.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 360      |
# |    ep_rew_mean        | -4.21    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 19500    |
# |    time_elapsed       | 192      |
# |    total_timesteps    | 97500    |
# | train/                |          |
# |    entropy_loss       | -0.443   |
# |    explained_variance | 0.835    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19499    |
# |    policy_loss        | -0.666   |
# |    value_loss         | 2.77     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 359      |
# |    ep_rew_mean        | -8.87    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 19600    |
# |    time_elapsed       | 193      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -0.213   |
# |    explained_variance | -0.016   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19599    |
# |    policy_loss        | -0.199   |
# |    value_loss         | 13.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 363      |
# |    ep_rew_mean        | -5.88    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 19700    |
# |    time_elapsed       | 194      |
# |    total_timesteps    | 98500    |
# | train/                |          |
# |    entropy_loss       | -0.494   |
# |    explained_variance | 0.434    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19699    |
# |    policy_loss        | 0.385    |
# |    value_loss         | 5.72     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 363      |
# |    ep_rew_mean        | -5.88    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 19800    |
# |    time_elapsed       | 195      |
# |    total_timesteps    | 99000    |
# | train/                |          |
# |    entropy_loss       | -0.535   |
# |    explained_variance | -1.12    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19799    |
# |    policy_loss        | 0.344    |
# |    value_loss         | 47.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 364      |
# |    ep_rew_mean        | -7       |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 19900    |
# |    time_elapsed       | 196      |
# |    total_timesteps    | 99500    |
# | train/                |          |
# |    entropy_loss       | -0.421   |
# |    explained_variance | 0.861    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19899    |
# |    policy_loss        | 3.73     |
# |    value_loss         | 48.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 365      |
# |    ep_rew_mean        | -7.72    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 20000    |
# |    time_elapsed       | 197      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -0.898   |
# |    explained_variance | -4.78    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19999    |
# |    policy_loss        | 4.25     |
# |    value_loss         | 52.9     |
# ------------------------------------
# C:\Users\art\anaconda3\envs\pytorch\lib\site-packages\gymnasium\envs\box2d\lunar_lander.py:681: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym.make("LunarLander-v2", render_mode="rgb_array")
#   gym.logger.warn(

# %%
env.close()

# %% [markdown]
# #### 7. Try PPO

# %%
from stable_baselines3 import PPO

# %%
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=100000)
episodes=10
for ep in range (episodes):
    obs = env.reset()
    done = False
    while not done:
        env.render()
        obs,reward,done, info, _ =env.step(env.action_space.sample())
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 886      |
# |    ep_rew_mean     | -75.9    |
# | time/              |          |
# |    fps             | 740      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 943        |
# |    ep_rew_mean          | -42.4      |
# | time/                   |            |
# |    fps                  | 625        |
# |    iterations           | 2          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00767214 |
# |    clip_fraction        | 0.0633     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.887     |
# |    explained_variance   | 0.525      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 31.1       |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.00395   |
# |    value_loss           | 46.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 962         |
# |    ep_rew_mean          | -24.9       |
# | time/                   |             |
# |    fps                  | 599         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008184065 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.986      |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.15        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00623    |
# |    value_loss           | 13.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 972          |
# |    ep_rew_mean          | -29.8        |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 4            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0046311105 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.953       |
# |    explained_variance   | 0.828        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.79         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00304     |
# |    value_loss           | 16.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 977         |
# |    ep_rew_mean          | -26.4       |
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 5           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005082459 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.934      |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.21        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00302    |
# |    value_loss           | 4.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 957         |
# |    ep_rew_mean          | -47.2       |
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 6           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005069038 |
# |    clip_fraction        | 0.0475      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.64        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00213    |
# |    value_loss           | 9.56        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 963          |
# |    ep_rew_mean          | -38.4        |
# | time/                   |              |
# |    fps                  | 581          |
# |    iterations           | 7            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0042978115 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.888       |
# |    explained_variance   | 0.627        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.4         |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.00194     |
# |    value_loss           | 65.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 964          |
# |    ep_rew_mean          | -40.9        |
# | time/                   |              |
# |    fps                  | 577          |
# |    iterations           | 8            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0031263279 |
# |    clip_fraction        | 0.0485       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.896       |
# |    explained_variance   | 0.889        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.83         |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00393     |
# |    value_loss           | 10.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 951          |
# |    ep_rew_mean          | -34.9        |
# | time/                   |              |
# |    fps                  | 573          |
# |    iterations           | 9            |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0040942943 |
# |    clip_fraction        | 0.0253       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.899       |
# |    explained_variance   | 0.796        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.9         |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00246     |
# |    value_loss           | 42           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 953          |
# |    ep_rew_mean          | -24.5        |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 10           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0039730384 |
# |    clip_fraction        | 0.0209       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.903       |
# |    explained_variance   | 0.4          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37           |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 96.7         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 957        |
# |    ep_rew_mean          | -19.9      |
# | time/                   |            |
# |    fps                  | 571        |
# |    iterations           | 11         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00451665 |
# |    clip_fraction        | 0.0344     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.862     |
# |    explained_variance   | 0.342      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.7       |
# |    n_updates            | 590        |
# |    policy_gradient_loss | -0.00241   |
# |    value_loss           | 60.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | -19         |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 12          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.005810839 |
# |    clip_fraction        | 0.0931      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.904      |
# |    explained_variance   | 0.389       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.59        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0025     |
# |    value_loss           | 57.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 963          |
# |    ep_rew_mean          | -12.8        |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 13           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0072658076 |
# |    clip_fraction        | 0.0622       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.932       |
# |    explained_variance   | 0.814        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.68         |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.001       |
# |    value_loss           | 8.87         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 966         |
# |    ep_rew_mean          | -12.7       |
# | time/                   |             |
# |    fps                  | 572         |
# |    iterations           | 14          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004652951 |
# |    clip_fraction        | 0.0348      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.885      |
# |    explained_variance   | 0.433       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.8         |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00361    |
# |    value_loss           | 54.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 968         |
# |    ep_rew_mean          | -10.4       |
# | time/                   |             |
# |    fps                  | 572         |
# |    iterations           | 15          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.006678998 |
# |    clip_fraction        | 0.0548      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.889      |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.4         |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.00448    |
# |    value_loss           | 15.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 968        |
# |    ep_rew_mean          | -3.93      |
# | time/                   |            |
# |    fps                  | 571        |
# |    iterations           | 16         |
# |    time_elapsed         | 57         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.00462862 |
# |    clip_fraction        | 0.0435     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.892     |
# |    explained_variance   | 0.783      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.2        |
# |    n_updates            | 640        |
# |    policy_gradient_loss | -0.00069   |
# |    value_loss           | 11.8       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 968          |
# |    ep_rew_mean          | 1.05         |
# | time/                   |              |
# |    fps                  | 572          |
# |    iterations           | 17           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0076948926 |
# |    clip_fraction        | 0.0586       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.861       |
# |    explained_variance   | 0.503        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.92         |
# |    n_updates            | 650          |
# |    policy_gradient_loss | -0.00242     |
# |    value_loss           | 58.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 968          |
# |    ep_rew_mean          | 2.78         |
# | time/                   |              |
# |    fps                  | 571          |
# |    iterations           | 18           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0049291104 |
# |    clip_fraction        | 0.0595       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.852       |
# |    explained_variance   | 0.444        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.6          |
# |    n_updates            | 660          |
# |    policy_gradient_loss | -0.00274     |
# |    value_loss           | 67.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 965          |
# |    ep_rew_mean          | 10.1         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 19           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0048207035 |
# |    clip_fraction        | 0.0493       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.838       |
# |    explained_variance   | 0.428        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.19         |
# |    n_updates            | 670          |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 66.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 959         |
# |    ep_rew_mean          | 17.7        |
# | time/                   |             |
# |    fps                  | 572         |
# |    iterations           | 20          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005909601 |
# |    clip_fraction        | 0.0383      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.877      |
# |    explained_variance   | 0.295       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71          |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.00294    |
# |    value_loss           | 89.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 950         |
# |    ep_rew_mean          | 27.5        |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 21          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.006881933 |
# |    clip_fraction        | 0.0535      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.863      |
# |    explained_variance   | 0.424       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52          |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.00125    |
# |    value_loss           | 82.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 945          |
# |    ep_rew_mean          | 33.2         |
# | time/                   |              |
# |    fps                  | 575          |
# |    iterations           | 22           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0043486264 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.787       |
# |    explained_variance   | 0.469        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.3         |
# |    n_updates            | 700          |
# |    policy_gradient_loss | -0.000763    |
# |    value_loss           | 110          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 939          |
# |    ep_rew_mean          | 40           |
# | time/                   |              |
# |    fps                  | 574          |
# |    iterations           | 23           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0050567733 |
# |    clip_fraction        | 0.0411       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.829       |
# |    explained_variance   | 0.546        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.51         |
# |    n_updates            | 710          |
# |    policy_gradient_loss | -0.00138     |
# |    value_loss           | 75.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 939         |
# |    ep_rew_mean          | 44.4        |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 24          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005898645 |
# |    clip_fraction        | 0.055       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.828      |
# |    explained_variance   | 0.593       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.6        |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.00243    |
# |    value_loss           | 95          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 938         |
# |    ep_rew_mean          | 47.1        |
# | time/                   |             |
# |    fps                  | 572         |
# |    iterations           | 25          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.003322427 |
# |    clip_fraction        | 0.0619      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.865      |
# |    explained_variance   | 0.645       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.6        |
# |    n_updates            | 730         |
# |    policy_gradient_loss | -0.00215    |
# |    value_loss           | 64.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 937         |
# |    ep_rew_mean          | 48.2        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 26          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.006855647 |
# |    clip_fraction        | 0.0746      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.85       |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.9        |
# |    n_updates            | 740         |
# |    policy_gradient_loss | -0.00226    |
# |    value_loss           | 51.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 934         |
# |    ep_rew_mean          | 46.1        |
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 27          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008014724 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.842      |
# |    explained_variance   | 0.779       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.6        |
# |    n_updates            | 750         |
# |    policy_gradient_loss | -0.00521    |
# |    value_loss           | 27.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 934          |
# |    ep_rew_mean          | 47.3         |
# | time/                   |              |
# |    fps                  | 571          |
# |    iterations           | 28           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0042882077 |
# |    clip_fraction        | 0.0514       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.782       |
# |    explained_variance   | 0.436        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43           |
# |    n_updates            | 760          |
# |    policy_gradient_loss | -0.0041      |
# |    value_loss           | 91           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 931          |
# |    ep_rew_mean          | 49.8         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 29           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0027832515 |
# |    clip_fraction        | 0.0402       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.77        |
# |    explained_variance   | 0.87         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.8         |
# |    n_updates            | 770          |
# |    policy_gradient_loss | -0.00184     |
# |    value_loss           | 19.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 928         |
# |    ep_rew_mean          | 49.3        |
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 30          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.011044973 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.861      |
# |    explained_variance   | 0.7         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.21        |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.0022     |
# |    value_loss           | 41.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 926        |
# |    ep_rew_mean          | 52         |
# | time/                   |            |
# |    fps                  | 571        |
# |    iterations           | 31         |
# |    time_elapsed         | 111        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.00417194 |
# |    clip_fraction        | 0.0475     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.756     |
# |    explained_variance   | 0.512      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 116        |
# |    n_updates            | 790        |
# |    policy_gradient_loss | -0.00239   |
# |    value_loss           | 118        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 925          |
# |    ep_rew_mean          | 53.8         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 32           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0072582327 |
# |    clip_fraction        | 0.0588       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.808       |
# |    explained_variance   | 0.752        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.1         |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.00267     |
# |    value_loss           | 37.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 925          |
# |    ep_rew_mean          | 55.1         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 33           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0023737275 |
# |    clip_fraction        | 0.0359       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.829       |
# |    explained_variance   | 0.833        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.2         |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.000326    |
# |    value_loss           | 36.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 925         |
# |    ep_rew_mean          | 55.8        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 34          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.005146539 |
# |    clip_fraction        | 0.0486      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.824      |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.49        |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.00173    |
# |    value_loss           | 48.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 920          |
# |    ep_rew_mean          | 54.9         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 35           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0087308725 |
# |    clip_fraction        | 0.0879       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.848       |
# |    explained_variance   | 0.883        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.99         |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.000789    |
# |    value_loss           | 17.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 915         |
# |    ep_rew_mean          | 54.9        |
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 36          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.006581614 |
# |    clip_fraction        | 0.0426      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.761      |
# |    explained_variance   | 0.453       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.3        |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.00164    |
# |    value_loss           | 124         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 907          |
# |    ep_rew_mean          | 55.7         |
# | time/                   |              |
# |    fps                  | 569          |
# |    iterations           | 37           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0058088778 |
# |    clip_fraction        | 0.048        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.86        |
# |    explained_variance   | 0.402        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 71.7         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 111          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 905         |
# |    ep_rew_mean          | 54.1        |
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 38          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.006559834 |
# |    clip_fraction        | 0.0663      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.787      |
# |    explained_variance   | 0.464       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.8        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.00295    |
# |    value_loss           | 129         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 903          |
# |    ep_rew_mean          | 50.2         |
# | time/                   |              |
# |    fps                  | 568          |
# |    iterations           | 39           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0072353818 |
# |    clip_fraction        | 0.0526       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.807       |
# |    explained_variance   | 0.423        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.5         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.000173    |
# |    value_loss           | 122          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 896          |
# |    ep_rew_mean          | 54.1         |
# | time/                   |              |
# |    fps                  | 568          |
# |    iterations           | 40           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0073533263 |
# |    clip_fraction        | 0.0744       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.813       |
# |    explained_variance   | 0.0181       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.92         |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 78.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 889          |
# |    ep_rew_mean          | 57.8         |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 41           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0018656413 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.798       |
# |    explained_variance   | 0.474        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19           |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.000525    |
# |    value_loss           | 55.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 889         |
# |    ep_rew_mean          | 59.1        |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 42          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.003038344 |
# |    clip_fraction        | 0.0353      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.77       |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.6        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.000122   |
# |    value_loss           | 59.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 889          |
# |    ep_rew_mean          | 60.9         |
# | time/                   |              |
# |    fps                  | 566          |
# |    iterations           | 43           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0029374766 |
# |    clip_fraction        | 0.0526       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.649       |
# |    explained_variance   | 0.836        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.5         |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00188     |
# |    value_loss           | 38.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 885         |
# |    ep_rew_mean          | 61.1        |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 44          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.004240402 |
# |    clip_fraction        | 0.0559      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.749      |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.1        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | 0.000551    |
# |    value_loss           | 37.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 883          |
# |    ep_rew_mean          | 65.4         |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 45           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0053756544 |
# |    clip_fraction        | 0.0511       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.744       |
# |    explained_variance   | 0.435        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.88         |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.001       |
# |    value_loss           | 99.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 878         |
# |    ep_rew_mean          | 65.3        |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 46          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.008190384 |
# |    clip_fraction        | 0.0468      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.804      |
# |    explained_variance   | 0.854       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.29        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.000662   |
# |    value_loss           | 28.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 874          |
# |    ep_rew_mean          | 71.1         |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 47           |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0047303764 |
# |    clip_fraction        | 0.0587       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.834       |
# |    explained_variance   | 0.281        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 249          |
# |    n_updates            | 950          |
# |    policy_gradient_loss | 5.4e-05      |
# |    value_loss           | 86.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 873         |
# |    ep_rew_mean          | 74.1        |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 48          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009003321 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.794      |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.7        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0014     |
# |    value_loss           | 35.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 873          |
# |    ep_rew_mean          | 75.7         |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 49           |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0047160825 |
# |    clip_fraction        | 0.0478       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.736       |
# |    explained_variance   | 0.812        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.4         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.000169    |
# |    value_loss           | 26.1         |
# ------------------------------------------

# %% [markdown]
# #### 8. Saving interim models

# %%
import os

# %%
model = PPO('MlpPolicy', env, verbose=1,tensorboard_log=logdir)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Create directories for saving models and logs if they don't exist
models_dir = 'models/PPO'
logdir = 'logs'

# Create the models directory if it doesn't exist
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

# Create the logs directory if it doesn't exist
if not os.path.exists(logdir):
    os.makedirs(logdir)

# %% [markdown]
# ### Understanding the below PPO Snippet
#
# #### Initialization: `model = PPO('MlpPolicy', env, verbose=1)`
#
# - **`'MlpPolicy'`**: This specifies that the policy network architecture will be a Multi-Layer Perceptron (MLP). MLPs are generally good for simpler, lower-dimensional observation spaces.
#
# - **`env`**: This is the environment object where the agent will be trained. It should comply with OpenAI's Gym API, providing methods like `reset()` and `step()`.
#
# - **`verbose=1`**: This sets the logging level to verbose, meaning that training progress will be printed to the console. This is useful for debugging and monitoring.
#
# #### Training Loop: `for i in range(1, 30):`
#
# - **`TIMESTEPS = 10000`**: This sets the number of timesteps for which the model will be trained in each iteration of the loop. 10,000 timesteps is a reasonable starting point for many problems but may need to be adjusted based on the complexity of the task.
#
# - **`model.learn(...)`**: This is where the actual training happens.
#
#   - **`total_timesteps=TIMESTEPS`**: Specifies the number of timesteps for this training iteration.
#
#   - **`reset_num_timesteps=False`**: This ensures that the learning continues from where it left off in the previous iteration, rather than resetting. This is crucial for incremental learning.
#
#   - **`tb_log_name='PPO'`**: This sets the name of the TensorBoard log, useful for monitoring training metrics.
#
# - **`model.save(f"(models_dir)/{TIMESTEPS*i})`**: This saves the model after each training iteration. The filename includes the total number of timesteps the model has been trained for, which is useful for keeping track of training progress and for potential rollbacks to previous states.
#
# The rationale behind this code is to incrementally train a PPO model for a total of 30 iterations, each with 10,000 timesteps, while saving the model at each step. This allows for monitoring and potentially resuming training from a specific point. The verbose logging and TensorBoard support provide avenues for debugging and performance tracking.

# %%
model = PPO('MlpPolicy', env, verbose=1,tensorboard_log=logdir)

TIMESTEPS = 10000
for i in range (1,30):
    model.learn(total_timesteps=TIMESTEPS,reset_num_timesteps=False, tb_log_name='PPO')
    model.save(f"{models_dir}/{TIMESTEPS*i}")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93       |
# |    ep_rew_mean     | -227     |
# | time/              |          |
# |    fps             | 740      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 98.3         |
# |    ep_rew_mean          | -198         |
# | time/                   |              |
# |    fps                  | 637          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0059515145 |
# |    clip_fraction        | 0.011        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00834      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 662          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00399     |
# |    value_loss           | 1.87e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.5        |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 609         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011306247 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00498     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 393         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 1.06e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.4        |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010827686 |
# |    clip_fraction        | 0.0607      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0285     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 535         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00964    |
# |    value_loss           | 861         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 99.9         |
# |    ep_rew_mean          | -181         |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 5            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0092622815 |
# |    clip_fraction        | 0.0719       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00184     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 462          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00905     |
# |    value_loss           | 942          |
# ------------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -161     |
# | time/              |          |
# |    fps             | 939      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 12288    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -153        |
# | time/                   |             |
# |    fps                  | 692         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008461328 |
# |    clip_fraction        | 0.096       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.056      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 225         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 556         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | -145        |
# | time/                   |             |
# |    fps                  | 643         |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008679049 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -0.000249   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 331         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00691    |
# |    value_loss           | 497         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 115         |
# |    ep_rew_mean          | -142        |
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008045707 |
# |    clip_fraction        | 0.0246      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.00252     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 135         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00448    |
# |    value_loss           | 546         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 115        |
# |    ep_rew_mean          | -123       |
# | time/                   |            |
# |    fps                  | 607        |
# |    iterations           | 5          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00611158 |
# |    clip_fraction        | 0.0436     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.29      |
# |    explained_variance   | 0.0127     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 115        |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00926   |
# |    value_loss           | 294        |
# ----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | -114     |
# | time/              |          |
# |    fps             | 885      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 22528    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 697         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012837132 |
# |    clip_fraction        | 0.0855      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | -0.0792     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 108         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00424    |
# |    value_loss           | 401         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | -112        |
# | time/                   |             |
# |    fps                  | 644         |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.012299584 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.000952    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 133         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00808    |
# |    value_loss           | 314         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -104        |
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007942139 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | -0.000427   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 190         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00865    |
# |    value_loss           | 442         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 607         |
# |    iterations           | 5           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008068056 |
# |    clip_fraction        | 0.0141      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | -0.00184    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 89.7        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00495    |
# |    value_loss           | 216         |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 175      |
# |    ep_rew_mean     | -98.5    |
# | time/              |          |
# |    fps             | 915      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 32768    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 190         |
# |    ep_rew_mean          | -94.5       |
# | time/                   |             |
# |    fps                  | 692         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.006757085 |
# |    clip_fraction        | 0.0982      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.00334    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 103         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00987    |
# |    value_loss           | 225         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -94.9       |
# | time/                   |             |
# |    fps                  | 641         |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010471014 |
# |    clip_fraction        | 0.0571      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.0412      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 87.4        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00523    |
# |    value_loss           | 122         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 212          |
# |    ep_rew_mean          | -93.1        |
# | time/                   |              |
# |    fps                  | 615          |
# |    iterations           | 4            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0064790575 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.0493       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 110          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0043      |
# |    value_loss           | 239          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | -86.5       |
# | time/                   |             |
# |    fps                  | 603         |
# |    iterations           | 5           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.012770705 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.044       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.2        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 145         |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 237      |
# |    ep_rew_mean     | -80.1    |
# | time/              |          |
# |    fps             | 907      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 43008    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 260         |
# |    ep_rew_mean          | -80.9       |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009411847 |
# |    clip_fraction        | 0.0793      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.084       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 126         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00679    |
# |    value_loss           | 208         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 278        |
# |    ep_rew_mean          | -79.8      |
# | time/                   |            |
# |    fps                  | 651        |
# |    iterations           | 3          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01179202 |
# |    clip_fraction        | 0.123      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | -0.0999    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 30.8       |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00559   |
# |    value_loss           | 164        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 289         |
# |    ep_rew_mean          | -78.2       |
# | time/                   |             |
# |    fps                  | 633         |
# |    iterations           | 4           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006717786 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.985      |
# |    explained_variance   | 0.538       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.7        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00614    |
# |    value_loss           | 35.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 313          |
# |    ep_rew_mean          | -72.2        |
# | time/                   |              |
# |    fps                  | 611          |
# |    iterations           | 5            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0059109065 |
# |    clip_fraction        | 0.0466       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.886       |
# |    explained_variance   | 0.44         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.6         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00563     |
# |    value_loss           | 49.3         |
# ------------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 327      |
# |    ep_rew_mean     | -69.8    |
# | time/              |          |
# |    fps             | 863      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 53248    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 347         |
# |    ep_rew_mean          | -64.6       |
# | time/                   |             |
# |    fps                  | 666         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.009288872 |
# |    clip_fraction        | 0.08        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.999      |
# |    explained_variance   | 0.196       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.5        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00674    |
# |    value_loss           | 93.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 361          |
# |    ep_rew_mean          | -63.1        |
# | time/                   |              |
# |    fps                  | 615          |
# |    iterations           | 3            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0057210596 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.858       |
# |    explained_variance   | 0.14         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.7         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00327     |
# |    value_loss           | 174          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 379         |
# |    ep_rew_mean          | -60         |
# | time/                   |             |
# |    fps                  | 591         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.007310686 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.962      |
# |    explained_variance   | 0.167       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 74.6        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00749    |
# |    value_loss           | 74.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 396         |
# |    ep_rew_mean          | -57.8       |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 5           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.007945891 |
# |    clip_fraction        | 0.0577      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.897      |
# |    explained_variance   | 0.639       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.36        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00364    |
# |    value_loss           | 18.7        |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 419      |
# |    ep_rew_mean     | -49.8    |
# | time/              |          |
# |    fps             | 852      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 63488    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 431         |
# |    ep_rew_mean          | -46.4       |
# | time/                   |             |
# |    fps                  | 655         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011590729 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.8        |
# |    explained_variance   | 0.444       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 90.2        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00518    |
# |    value_loss           | 62.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 451        |
# |    ep_rew_mean          | -38.8      |
# | time/                   |            |
# |    fps                  | 608        |
# |    iterations           | 3          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.00845368 |
# |    clip_fraction        | 0.037      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.447      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 66.2       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00127   |
# |    value_loss           | 58.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 468         |
# |    ep_rew_mean          | -35         |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006384302 |
# |    clip_fraction        | 0.089       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.753      |
# |    explained_variance   | 0.424       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.9        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00359    |
# |    value_loss           | 110         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 485          |
# |    ep_rew_mean          | -28.1        |
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 5            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0062877997 |
# |    clip_fraction        | 0.0831       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.859        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.99         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00489     |
# |    value_loss           | 12.7         |
# ------------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 493      |
# |    ep_rew_mean     | -23      |
# | time/              |          |
# |    fps             | 875      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 73728    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 514          |
# |    ep_rew_mean          | -20.1        |
# | time/                   |              |
# |    fps                  | 682          |
# |    iterations           | 2            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0027606494 |
# |    clip_fraction        | 0.0386       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.668        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.93         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 52           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 532          |
# |    ep_rew_mean          | -17.1        |
# | time/                   |              |
# |    fps                  | 633          |
# |    iterations           | 3            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0023054006 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.876       |
# |    explained_variance   | 0.589        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.4         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00285     |
# |    value_loss           | 99.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 543         |
# |    ep_rew_mean          | -12.1       |
# | time/                   |             |
# |    fps                  | 612         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.010990607 |
# |    clip_fraction        | 0.0526      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.667       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.2        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00342    |
# |    value_loss           | 87.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 561         |
# |    ep_rew_mean          | -1.66       |
# | time/                   |             |
# |    fps                  | 599         |
# |    iterations           | 5           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.006149698 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.954      |
# |    explained_variance   | 0.674       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.91        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00233    |
# |    value_loss           | 64          |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 577      |
# |    ep_rew_mean     | 1.31     |
# | time/              |          |
# |    fps             | 908      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 83968    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 587         |
# |    ep_rew_mean          | 7.73        |
# | time/                   |             |
# |    fps                  | 674         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.010871121 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.892      |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.9        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00501    |
# |    value_loss           | 60          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 604         |
# |    ep_rew_mean          | 10          |
# | time/                   |             |
# |    fps                  | 629         |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.004229461 |
# |    clip_fraction        | 0.0375      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.901      |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00353    |
# |    value_loss           | 72.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 621          |
# |    ep_rew_mean          | 12.8         |
# | time/                   |              |
# |    fps                  | 609          |
# |    iterations           | 4            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0069245324 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.969       |
# |    explained_variance   | 0.828        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.2          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00441     |
# |    value_loss           | 24.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 630          |
# |    ep_rew_mean          | 16.9         |
# | time/                   |              |
# |    fps                  | 595          |
# |    iterations           | 5            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0022811186 |
# |    clip_fraction        | 0.00723      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.956       |
# |    explained_variance   | 0.613        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 115          |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 113          |
# ------------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 645      |
# |    ep_rew_mean     | 20.3     |
# | time/              |          |
# |    fps             | 974      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 94208    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 654         |
# |    ep_rew_mean          | 28.3        |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.018067993 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.4         |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00432    |
# |    value_loss           | 69.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 666          |
# |    ep_rew_mean          | 33.8         |
# | time/                   |              |
# |    fps                  | 648          |
# |    iterations           | 3            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0053421957 |
# |    clip_fraction        | 0.0578       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.826       |
# |    explained_variance   | 0.686        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.5         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00182     |
# |    value_loss           | 70.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 682         |
# |    ep_rew_mean          | 37.2        |
# | time/                   |             |
# |    fps                  | 622         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.009135252 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.907      |
# |    explained_variance   | 0.544       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.33        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00668    |
# |    value_loss           | 48.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 693          |
# |    ep_rew_mean          | 43.6         |
# | time/                   |              |
# |    fps                  | 608          |
# |    iterations           | 5            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0034879213 |
# |    clip_fraction        | 0.0438       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.694       |
# |    explained_variance   | 0.835        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.7         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0035      |
# |    value_loss           | 55.6         |
# ------------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 701      |
# |    ep_rew_mean     | 46.1     |
# | time/              |          |
# |    fps             | 850      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 104448   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 716        |
# |    ep_rew_mean          | 46         |
# | time/                   |            |
# |    fps                  | 670        |
# |    iterations           | 2          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.01394224 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.962     |
# |    explained_variance   | 0.849      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.67       |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.00487   |
# |    value_loss           | 31.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 724         |
# |    ep_rew_mean          | 49.1        |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.007940476 |
# |    clip_fraction        | 0.0911      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.977      |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.18        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0032     |
# |    value_loss           | 11.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 739          |
# |    ep_rew_mean          | 51.5         |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 4            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0042893584 |
# |    clip_fraction        | 0.031        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.972       |
# |    explained_variance   | 0.524        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.8         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00203     |
# |    value_loss           | 84.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 747         |
# |    ep_rew_mean          | 52.3        |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 5           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.016109958 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.82        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00933    |
# |    value_loss           | 11.1        |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 763      |
# |    ep_rew_mean     | 55.8     |
# | time/              |          |
# |    fps             | 885      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 114688   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 773         |
# |    ep_rew_mean          | 55.8        |
# | time/                   |             |
# |    fps                  | 685         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.013987621 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.866       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.87        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 10.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 778          |
# |    ep_rew_mean          | 57.2         |
# | time/                   |              |
# |    fps                  | 637          |
# |    iterations           | 3            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0058644717 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.982       |
# |    explained_variance   | 0.71         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 93.4         |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00331     |
# |    value_loss           | 63.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 791         |
# |    ep_rew_mean          | 59.2        |
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.008655667 |
# |    clip_fraction        | 0.0346      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.78        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00222    |
# |    value_loss           | 94.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 791          |
# |    ep_rew_mean          | 62.7         |
# | time/                   |              |
# |    fps                  | 599          |
# |    iterations           | 5            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0042606723 |
# |    clip_fraction        | 0.0622       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.924       |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.62         |
# |    n_updates            | 590          |
# |    policy_gradient_loss | 0.000405     |
# |    value_loss           | 6.87         |
# ------------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 795      |
# |    ep_rew_mean     | 69.9     |
# | time/              |          |
# |    fps             | 1022     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 124928   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 795         |
# |    ep_rew_mean          | 71.5        |
# | time/                   |             |
# |    fps                  | 711         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.008043592 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.928      |
# |    explained_variance   | 0.913       |
# ...
# |    entropy_loss         | -0.89       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.408       |
# |    n_updates            | 1240        |
# |    policy_gradient_loss | -0.00246    |
# |    value_loss           | 6.44        |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 635      |
# |    ep_rew_mean     | 94.2     |
# | time/              |          |
# |    fps             | 899      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 258048   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 634         |
# |    ep_rew_mean          | 95.3        |
# | time/                   |             |
# |    fps                  | 685         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 260096      |
# | train/                  |             |
# |    approx_kl            | 0.004427365 |
# |    clip_fraction        | 0.0207      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.658      |
# |    explained_variance   | 0.708       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.1        |
# |    n_updates            | 1260        |
# |    policy_gradient_loss | -0.000549   |
# |    value_loss           | 126         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 646         |
# |    ep_rew_mean          | 96.4        |
# | time/                   |             |
# |    fps                  | 633         |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.009464871 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.823      |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.3        |
# |    n_updates            | 1270        |
# |    policy_gradient_loss | -0.00786    |
# |    value_loss           | 33.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 642         |
# |    ep_rew_mean          | 97.8        |
# | time/                   |             |
# |    fps                  | 612         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 264192      |
# | train/                  |             |
# |    approx_kl            | 0.007106837 |
# |    clip_fraction        | 0.0783      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.773      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.94        |
# |    n_updates            | 1280        |
# |    policy_gradient_loss | -0.00342    |
# |    value_loss           | 2.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 635         |
# |    ep_rew_mean          | 98.7        |
# | time/                   |             |
# |    fps                  | 598         |
# |    iterations           | 5           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 266240      |
# | train/                  |             |
# |    approx_kl            | 0.008475261 |
# |    clip_fraction        | 0.0811      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.7        |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.5        |
# |    n_updates            | 1290        |
# |    policy_gradient_loss | -0.0035     |
# |    value_loss           | 124         |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 630      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    fps             | 895      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 268288   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 632          |
# |    ep_rew_mean          | 106          |
# | time/                   |              |
# |    fps                  | 678          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 270336       |
# | train/                  |              |
# |    approx_kl            | 0.0049901484 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.713       |
# |    explained_variance   | 0.687        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 103          |
# |    n_updates            | 1310         |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 111          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 624         |
# |    ep_rew_mean          | 106         |
# | time/                   |             |
# |    fps                  | 632         |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 272384      |
# | train/                  |             |
# |    approx_kl            | 0.010741411 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.704      |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 128         |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | -0.00591    |
# |    value_loss           | 72.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 611          |
# |    ep_rew_mean          | 105          |
# | time/                   |              |
# |    fps                  | 609          |
# |    iterations           | 4            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 274432       |
# | train/                  |              |
# |    approx_kl            | 0.0066701174 |
# |    clip_fraction        | 0.0572       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.768       |
# |    explained_variance   | 0.729        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.3         |
# |    n_updates            | 1330         |
# |    policy_gradient_loss | -0.00232     |
# |    value_loss           | 123          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 619          |
# |    ep_rew_mean          | 107          |
# | time/                   |              |
# |    fps                  | 610          |
# |    iterations           | 5            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 276480       |
# | train/                  |              |
# |    approx_kl            | 0.0012960857 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.753       |
# |    explained_variance   | 0.81         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.3         |
# |    n_updates            | 1340         |
# |    policy_gradient_loss | -0.000348    |
# |    value_loss           | 90.9         |
# ------------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 621      |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    fps             | 846      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 278528   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 622         |
# |    ep_rew_mean          | 106         |
# | time/                   |             |
# |    fps                  | 695         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 280576      |
# | train/                  |             |
# |    approx_kl            | 0.023409195 |
# |    clip_fraction        | 0.0579      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.785      |
# |    explained_variance   | 0.638       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.3        |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | -0.000855   |
# |    value_loss           | 52.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 615         |
# |    ep_rew_mean          | 104         |
# | time/                   |             |
# |    fps                  | 648         |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 282624      |
# | train/                  |             |
# |    approx_kl            | 0.010298989 |
# |    clip_fraction        | 0.0918      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.796      |
# |    explained_variance   | 0.81        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.6        |
# |    n_updates            | 1370        |
# |    policy_gradient_loss | -0.00386    |
# |    value_loss           | 78.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 612         |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 284672      |
# | train/                  |             |
# |    approx_kl            | 0.022245418 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.767      |
# |    explained_variance   | 0.758       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 115         |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | -0.00169    |
# |    value_loss           | 113         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 589        |
# |    ep_rew_mean          | 99         |
# | time/                   |            |
# |    fps                  | 616        |
# |    iterations           | 5          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 286720     |
# | train/                  |            |
# |    approx_kl            | 0.01223904 |
# |    clip_fraction        | 0.0861     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.727     |
# |    explained_variance   | 0.795      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.47       |
# |    n_updates            | 1390       |
# |    policy_gradient_loss | -0.00608   |
# |    value_loss           | 100        |
# ----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 589      |
# |    ep_rew_mean     | 96.2     |
# | time/              |          |
# |    fps             | 913      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 288768   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 594          |
# |    ep_rew_mean          | 97.5         |
# | time/                   |              |
# |    fps                  | 712          |
# |    iterations           | 2            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 290816       |
# | train/                  |              |
# |    approx_kl            | 0.0036129644 |
# |    clip_fraction        | 0.0755       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.704       |
# |    explained_variance   | 0.764        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.3         |
# |    n_updates            | 1410         |
# |    policy_gradient_loss | -0.00278     |
# |    value_loss           | 83.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 601         |
# |    ep_rew_mean          | 98.5        |
# | time/                   |             |
# |    fps                  | 646         |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 292864      |
# | train/                  |             |
# |    approx_kl            | 0.011744201 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.677      |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.99        |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | 0.000571    |
# |    value_loss           | 34.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 581         |
# |    ep_rew_mean          | 99          |
# | time/                   |             |
# |    fps                  | 618         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.007891469 |
# |    clip_fraction        | 0.0821      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.709      |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16        |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | -0.000281   |
# |    value_loss           | 4.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 582         |
# |    ep_rew_mean          | 101         |
# | time/                   |             |
# |    fps                  | 598         |
# |    iterations           | 5           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 296960      |
# | train/                  |             |
# |    approx_kl            | 0.001930079 |
# |    clip_fraction        | 0.00195     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.68        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.3        |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | -0.00066    |
# |    value_loss           | 219         |
# -----------------------------------------

# %% [markdown]
# ##### also do this with A2C

# %%
# Create directories for saving models and logs if they don't exist
models_dir = 'models/A2C'
logdir = 'logs'

# Create the models directory if it doesn't exist
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

# Create the logs directory if it doesn't exist
if not os.path.exists(logdir):
    os.makedirs(logdir)

# %%
model = A2C('MlpPolicy', env, verbose=1,tensorboard_log=logdir)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
TIMESTEPS = 10000
for i in range (1,30):
    model.learn(total_timesteps=TIMESTEPS,reset_num_timesteps=False, tb_log_name='A2C')
    model.save(f"{models_dir}/{TIMESTEPS*i}")
# Out:
# Logging to logs\A2C_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 114      |
# |    ep_rew_mean        | -324     |
# | time/                 |          |
# |    fps                | 542      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.24    |
# |    explained_variance | 0.00477  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -13.1    |
# |    value_loss         | 200      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 117      |
# |    ep_rew_mean        | -317     |
# | time/                 |          |
# |    fps                | 562      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | 0.00598  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -11.5    |
# |    value_loss         | 138      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 134      |
# |    ep_rew_mean        | -326     |
# | time/                 |          |
# |    fps                | 572      |
# |    iterations         | 300      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.55    |
# |    explained_variance | 0.0024   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -1.31    |
# |    value_loss         | 104      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 139      |
# |    ep_rew_mean        | -358     |
# | time/                 |          |
# |    fps                | 576      |
# |    iterations         | 400      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.14    |
# |    explained_variance | -0.00221 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 3.3      |
# |    value_loss         | 20.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 148      |
# |    ep_rew_mean        | -364     |
# | time/                 |          |
# |    fps                | 577      |
# |    iterations         | 500      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.901   |
# |    explained_variance | 0.00167  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -3.08    |
# |    value_loss         | 70.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 147      |
# |    ep_rew_mean        | -358     |
# | time/                 |          |
# |    fps                | 576      |
# |    iterations         | 600      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -0.00254 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 4.18     |
# |    value_loss         | 29.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 152      |
# |    ep_rew_mean        | -342     |
# | time/                 |          |
# |    fps                | 571      |
# |    iterations         | 700      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.947   |
# |    explained_variance | 0.0412   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -12.1    |
# |    value_loss         | 163      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 152       |
# |    ep_rew_mean        | -339      |
# | time/                 |           |
# |    fps                | 565       |
# |    iterations         | 800       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -0.552    |
# |    explained_variance | -0.000785 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -0.134    |
# |    value_loss         | 7.88      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 159      |
# |    ep_rew_mean        | -327     |
# | time/                 |          |
# |    fps                | 556      |
# |    iterations         | 900      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.92    |
# |    explained_variance | -0.00031 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 1.87     |
# |    value_loss         | 94.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 166      |
# |    ep_rew_mean        | -321     |
# | time/                 |          |
# |    fps                | 554      |
# |    iterations         | 1000     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.961   |
# |    explained_variance | 0.000104 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -5.09    |
# |    value_loss         | 21.5     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 165       |
# |    ep_rew_mean        | -307      |
# | time/                 |           |
# |    fps                | 550       |
# |    iterations         | 1100      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -0.999    |
# |    explained_variance | -8.42e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -4.75     |
# |    value_loss         | 52.9      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 161      |
# |    ep_rew_mean        | -283     |
# | time/                 |          |
# |    fps                | 548      |
# |    iterations         | 1200     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.13    |
# |    explained_variance | 0.00386  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 11.7     |
# |    value_loss         | 112      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 165      |
# |    ep_rew_mean        | -277     |
# | time/                 |          |
# |    fps                | 545      |
# |    iterations         | 1300     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.826   |
# |    explained_variance | 9.18e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 3.95     |
# |    value_loss         | 47.3     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 167       |
# |    ep_rew_mean        | -273      |
# | time/                 |           |
# |    fps                | 543       |
# |    iterations         | 1400      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.801    |
# |    explained_variance | -5.73e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -16.8     |
# |    value_loss         | 202       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 169       |
# |    ep_rew_mean        | -268      |
# | time/                 |           |
# |    fps                | 541       |
# |    iterations         | 1500      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.74     |
# |    explained_variance | -0.000978 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 10.2      |
# |    value_loss         | 261       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 171       |
# |    ep_rew_mean        | -258      |
# | time/                 |           |
# |    fps                | 540       |
# |    iterations         | 1600      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.754    |
# |    explained_variance | -4.51e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 2.18      |
# |    value_loss         | 18.7      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 173       |
# |    ep_rew_mean        | -249      |
# | time/                 |           |
# |    fps                | 538       |
# |    iterations         | 1700      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -0.712    |
# |    explained_variance | -0.000711 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 16.1      |
# |    value_loss         | 683       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 176      |
# |    ep_rew_mean        | -249     |
# | time/                 |          |
# |    fps                | 537      |
# |    iterations         | 1800     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.648   |
# |    explained_variance | -5.2e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 4.98     |
# |    value_loss         | 87.5     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -245      |
# | time/                 |           |
# |    fps                | 533       |
# |    iterations         | 1900      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.819    |
# |    explained_variance | -1.12e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 0.816     |
# |    value_loss         | 1.98      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | -241     |
# | time/                 |          |
# |    fps                | 536      |
# |    iterations         | 2000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.778   |
# |    explained_variance | -2.4e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -1.52    |
# |    value_loss         | 14.9     |
# ------------------------------------
# Logging to logs\A2C_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 184      |
# |    ep_rew_mean        | -235     |
# | time/                 |          |
# |    fps                | 597      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.845   |
# |    explained_variance | -0.00148 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -4.69    |
# |    value_loss         | 994      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 184       |
# |    ep_rew_mean        | -232      |
# | time/                 |           |
# |    fps                | 595       |
# |    iterations         | 200       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -0.565    |
# |    explained_variance | -0.000645 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -0.297    |
# |    value_loss         | 2.54      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 187      |
# |    ep_rew_mean        | -226     |
# | time/                 |          |
# |    fps                | 594      |
# |    iterations         | 300      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -1.21    |
# |    explained_variance | 6.02e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.833    |
# |    value_loss         | 8.46     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 189       |
# |    ep_rew_mean        | -224      |
# | time/                 |           |
# |    fps                | 583       |
# |    iterations         | 400       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -0.823    |
# |    explained_variance | -5.72e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | 6.14      |
# |    value_loss         | 91.4      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 192       |
# |    ep_rew_mean        | -220      |
# | time/                 |           |
# |    fps                | 571       |
# |    iterations         | 500       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -0.301    |
# |    explained_variance | -2.06e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | 0.373     |
# |    value_loss         | 20.5      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 192       |
# |    ep_rew_mean        | -219      |
# | time/                 |           |
# |    fps                | 561       |
# |    iterations         | 600       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -0.478    |
# |    explained_variance | -7.15e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | 10.8      |
# |    value_loss         | 208       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 193       |
# |    ep_rew_mean        | -215      |
# | time/                 |           |
# |    fps                | 551       |
# |    iterations         | 700       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -0.209    |
# |    explained_variance | -1.07e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | 0.253     |
# |    value_loss         | 60.8      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 196      |
# |    ep_rew_mean        | -213     |
# | time/                 |          |
# |    fps                | 543      |
# |    iterations         | 800      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.819   |
# |    explained_variance | 2.26e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -1.37    |
# |    value_loss         | 28.1     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 197       |
# |    ep_rew_mean        | -212      |
# | time/                 |           |
# |    fps                | 537       |
# |    iterations         | 900       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -0.745    |
# |    explained_variance | -1.19e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | 5.8       |
# |    value_loss         | 134       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 199       |
# |    ep_rew_mean        | -213      |
# | time/                 |           |
# |    fps                | 532       |
# |    iterations         | 1000      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.606    |
# |    explained_variance | -5.96e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | 3.92      |
# |    value_loss         | 99.6      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 199       |
# |    ep_rew_mean        | -213      |
# | time/                 |           |
# |    fps                | 528       |
# |    iterations         | 1100      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -0.457    |
# |    explained_variance | -0.000122 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | 0.125     |
# |    value_loss         | 0.828     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 204      |
# |    ep_rew_mean        | -205     |
# | time/                 |          |
# |    fps                | 524      |
# |    iterations         | 1200     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.745   |
# |    explained_variance | 5.16e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -2.52    |
# |    value_loss         | 19.3     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 208       |
# |    ep_rew_mean        | -199      |
# | time/                 |           |
# |    fps                | 519       |
# |    iterations         | 1300      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -0.318    |
# |    explained_variance | -1.34e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -1.43     |
# |    value_loss         | 3.83      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 209       |
# |    ep_rew_mean        | -199      |
# | time/                 |           |
# |    fps                | 515       |
# |    iterations         | 1400      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -0.688    |
# |    explained_variance | -4.48e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | 4.25      |
# |    value_loss         | 47        |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | -199     |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 1500     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.585   |
# |    explained_variance | 7.26e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -1.14    |
# |    value_loss         | 4.22     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 210       |
# |    ep_rew_mean        | -200      |
# | time/                 |           |
# |    fps                | 514       |
# |    iterations         | 1600      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -0.787    |
# |    explained_variance | -3.84e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -3.37     |
# |    value_loss         | 40.4      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 211      |
# |    ep_rew_mean        | -198     |
# | time/                 |          |
# |    fps                | 518      |
# |    iterations         | 1700     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.808   |
# |    explained_variance | 0.000894 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -3.33    |
# |    value_loss         | 53.2     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 213       |
# |    ep_rew_mean        | -197      |
# | time/                 |           |
# |    fps                | 522       |
# |    iterations         | 1800      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -0.994    |
# |    explained_variance | -9.48e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | -1.63     |
# |    value_loss         | 4.61      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 214      |
# |    ep_rew_mean        | -198     |
# | time/                 |          |
# |    fps                | 525      |
# |    iterations         | 1900     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.603   |
# |    explained_variance | 3.27e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 2.49     |
# |    value_loss         | 7.86     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 216      |
# |    ep_rew_mean        | -193     |
# | time/                 |          |
# |    fps                | 528      |
# |    iterations         | 2000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.612   |
# |    explained_variance | 0.000177 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -2.04    |
# |    value_loss         | 76.4     |
# ------------------------------------
# Logging to logs\A2C_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 216      |
# |    ep_rew_mean        | -189     |
# | time/                 |          |
# |    fps                | 576      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -1.25    |
# |    explained_variance | 2.46e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -5.1     |
# |    value_loss         | 30.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 217      |
# |    ep_rew_mean        | -189     |
# | time/                 |          |
# |    fps                | 568      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.763   |
# |    explained_variance | 0.000438 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.627   |
# |    value_loss         | 4.25     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 219      |
# |    ep_rew_mean        | -189     |
# | time/                 |          |
# |    fps                | 558      |
# |    iterations         | 300      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.171   |
# |    explained_variance | -0.138   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -46.5    |
# |    value_loss         | 1.17e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 219      |
# |    ep_rew_mean        | -190     |
# | time/                 |          |
# |    fps                | 550      |
# |    iterations         | 400      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.682   |
# |    explained_variance | 7.93e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 1.38     |
# |    value_loss         | 5.29     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 222       |
# |    ep_rew_mean        | -187      |
# | time/                 |           |
# |    fps                | 544       |
# |    iterations         | 500       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -0.555    |
# |    explained_variance | -1.45e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -0.828    |
# |    value_loss         | 16.3      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 225       |
# |    ep_rew_mean        | -180      |
# | time/                 |           |
# |    fps                | 540       |
# |    iterations         | 600       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -0.682    |
# |    explained_variance | -1.67e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | 4.06      |
# |    value_loss         | 117       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 226       |
# |    ep_rew_mean        | -174      |
# | time/                 |           |
# |    fps                | 537       |
# |    iterations         | 700       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -0.712    |
# |    explained_variance | -8.94e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | 4.29      |
# |    value_loss         | 43        |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 229       |
# |    ep_rew_mean        | -174      |
# | time/                 |           |
# |    fps                | 531       |
# |    iterations         | 800       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -0.723    |
# |    explained_variance | -3.34e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | 4.44      |
# |    value_loss         | 49.6      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 230      |
# |    ep_rew_mean        | -170     |
# | time/                 |          |
# |    fps                | 528      |
# |    iterations         | 900      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -0.888   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -3.66    |
# |    value_loss         | 32.3     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 233       |
# |    ep_rew_mean        | -165      |
# | time/                 |           |
# |    fps                | 529       |
# |    iterations         | 1000      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -0.562    |
# |    explained_variance | -2.62e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | -1.95     |
# |    value_loss         | 21.7      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 234       |
# |    ep_rew_mean        | -158      |
# | time/                 |           |
# |    fps                | 528       |
# |    iterations         | 1100      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -0.645    |
# |    explained_variance | -1.07e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | 7.41      |
# |    value_loss         | 355       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 234      |
# |    ep_rew_mean        | -154     |
# | time/                 |          |
# |    fps                | 528      |
# |    iterations         | 1200     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.132   |
# |    explained_variance | 0.000259 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -5.18    |
# |    value_loss         | 47.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 236      |
# |    ep_rew_mean        | -148     |
# | time/                 |          |
# |    fps                | 527      |
# |    iterations         | 1300     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -0.687   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 2.87     |
# |    value_loss         | 23.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 236      |
# |    ep_rew_mean        | -148     |
# | time/                 |          |
# |    fps                | 524      |
# |    iterations         | 1400     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -1.18    |
# |    explained_variance | -0.597   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -5.48    |
# |    value_loss         | 66.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 245      |
# |    ep_rew_mean        | -141     |
# | time/                 |          |
# |    fps                | 523      |
# |    iterations         | 1500     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.912   |
# |    explained_variance | 4.77e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | -4.58    |
# |    value_loss         | 32.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 246      |
# |    ep_rew_mean        | -140     |
# | time/                 |          |
# |    fps                | 522      |
# |    iterations         | 1600     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.244   |
# |    explained_variance | 0.0112   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | -4.1     |
# |    value_loss         | 30.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 247      |
# |    ep_rew_mean        | -138     |
# | time/                 |          |
# |    fps                | 521      |
# |    iterations         | 1700     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -0.786   |
# |    explained_variance | -0.125   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.0804  |
# |    value_loss         | 0.0564   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 247      |
# |    ep_rew_mean        | -138     |
# | time/                 |          |
# |    fps                | 520      |
# |    iterations         | 1800     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.645   |
# |    explained_variance | -0.0215  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.0387  |
# |    value_loss         | 0.0232   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 255      |
# |    ep_rew_mean        | -136     |
# | time/                 |          |
# |    fps                | 519      |
# |    iterations         | 1900     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | 0.012    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.355    |
# |    value_loss         | 0.302    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 262      |
# |    ep_rew_mean        | -132     |
# | time/                 |          |
# |    fps                | 518      |
# |    iterations         | 2000     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.201   |
# |    explained_variance | -0.00128 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.0606   |
# |    value_loss         | 4.8      |
# ------------------------------------
# Logging to logs\A2C_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 262      |
# |    ep_rew_mean        | -132     |
# | time/                 |          |
# |    fps                | 513      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.458   |
# |    explained_variance | 0.232    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -3.55    |
# |    value_loss         | 583      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 269       |
# |    ep_rew_mean        | -130      |
# | time/                 |           |
# |    fps                | 512       |
# |    iterations         | 200       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -0.32     |
# |    explained_variance | -1.39e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | 4.58      |
# |    value_loss         | 101       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 268      |
# |    ep_rew_mean        | -131     |
# | time/                 |          |
# |    fps                | 509      |
# |    iterations         | 300      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -0.18    |
# |    explained_variance | -0.0133  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.188    |
# |    value_loss         | 25.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 273      |
# |    ep_rew_mean        | -127     |
# | time/                 |          |
# |    fps                | 505      |
# |    iterations         | 400      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.675   |
# |    explained_variance | -0.00133 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 4.57     |
# |    value_loss         | 66.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 274      |
# |    ep_rew_mean        | -127     |
# | time/                 |          |
# |    fps                | 504      |
# |    iterations         | 500      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.957   |
# |    explained_variance | -0.00114 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -9.6     |
# |    value_loss         | 102      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 279       |
# |    ep_rew_mean        | -126      |
# | time/                 |           |
# |    fps                | 502       |
# |    iterations         | 600       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -0.316    |
# |    explained_variance | -0.000693 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | -0.211    |
# |    value_loss         | 2.96      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 280      |
# |    ep_rew_mean        | -125     |
# | time/                 |          |
# |    fps                | 502      |
# |    iterations         | 700      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.538   |
# |    explained_variance | 3.98e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -0.293   |
# |    value_loss         | 2.28     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 283      |
# |    ep_rew_mean        | -127     |
# | time/                 |          |
# |    fps                | 501      |
# |    iterations         | 800      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.167   |
# |    explained_variance | -1.5     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.195   |
# |    value_loss         | 2.96e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 285      |
# |    ep_rew_mean        | -125     |
# | time/                 |          |
# |    fps                | 501      |
# |    iterations         | 900      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.529   |
# |    explained_variance | -0.0412  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 6.02     |
# |    value_loss         | 108      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 286      |
# |    ep_rew_mean        | -123     |
# | time/                 |          |
# |    fps                | 502      |
# |    iterations         | 1000     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -0.302   |
# |    explained_variance | 0.00751  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | -0.279   |
# |    value_loss         | 0.219    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 289       |
# |    ep_rew_mean        | -122      |
# | time/                 |           |
# |    fps                | 502       |
# |    iterations         | 1100      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -0.539    |
# |    explained_variance | -0.000424 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | 1.77      |
# |    value_loss         | 147       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 288      |
# |    ep_rew_mean        | -121     |
# | time/                 |          |
# |    fps                | 502      |
# |    iterations         | 1200     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.233   |
# |    explained_variance | -0.00196 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | -0.00544 |
# |    value_loss         | 0.014    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 290      |
# |    ep_rew_mean        | -116     |
# | time/                 |          |
# |    fps                | 501      |
# |    iterations         | 1300     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -0.253   |
# |    explained_variance | -0.00156 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | 5.21     |
# |    value_loss         | 415      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 292      |
# |    ep_rew_mean        | -115     |
# | time/                 |          |
# |    fps                | 500      |
# |    iterations         | 1400     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -0.666   |
# |    explained_variance | -0.173   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | 1.04     |
# |    value_loss         | 2.77     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 292      |
# |    ep_rew_mean        | -116     |
# | time/                 |          |
# |    fps                | 502      |
# |    iterations         | 1500     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -0.272   |
# |    explained_variance | -0.0144  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | -0.011   |
# |    value_loss         | 0.0372   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 294      |
# |    ep_rew_mean        | -111     |
# | time/                 |          |
# |    fps                | 501      |
# |    iterations         | 1600     |
# ...
# |    explained_variance | 0.263    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 55499    |
# |    policy_loss        | -0.352   |
# |    value_loss         | 0.929    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 807      |
# |    ep_rew_mean        | -17.4    |
# | time/                 |          |
# |    fps                | 523      |
# |    iterations         | 1600     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 278000   |
# | train/                |          |
# |    entropy_loss       | -0.489   |
# |    explained_variance | -0.903   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 55599    |
# |    policy_loss        | -0.166   |
# |    value_loss         | 0.911    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 807      |
# |    ep_rew_mean        | -17.4    |
# | time/                 |          |
# |    fps                | 527      |
# |    iterations         | 1700     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 278500   |
# | train/                |          |
# |    entropy_loss       | -0.27    |
# |    explained_variance | 0.0589   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 55699    |
# |    policy_loss        | -1.43    |
# |    value_loss         | 12.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 818      |
# |    ep_rew_mean        | -17.8    |
# | time/                 |          |
# |    fps                | 530      |
# |    iterations         | 1800     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 279000   |
# | train/                |          |
# |    entropy_loss       | -0.409   |
# |    explained_variance | -0.639   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 55799    |
# |    policy_loss        | 0.13     |
# |    value_loss         | 1.18     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 818      |
# |    ep_rew_mean        | -17.8    |
# | time/                 |          |
# |    fps                | 533      |
# |    iterations         | 1900     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 279500   |
# | train/                |          |
# |    entropy_loss       | -0.425   |
# |    explained_variance | 0.434    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 55899    |
# |    policy_loss        | -0.347   |
# |    value_loss         | 1.92     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 826      |
# |    ep_rew_mean        | -18.9    |
# | time/                 |          |
# |    fps                | 532      |
# |    iterations         | 2000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 280000   |
# | train/                |          |
# |    entropy_loss       | -0.327   |
# |    explained_variance | 0.938    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 55999    |
# |    policy_loss        | 0.244    |
# |    value_loss         | 2.66     |
# ------------------------------------
# Logging to logs\A2C_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 826      |
# |    ep_rew_mean        | -18.9    |
# | time/                 |          |
# |    fps                | 523      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 280500   |
# | train/                |          |
# |    entropy_loss       | -0.298   |
# |    explained_variance | 0.768    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 56099    |
# |    policy_loss        | -0.0489  |
# |    value_loss         | 0.719    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 835      |
# |    ep_rew_mean        | -19.6    |
# | time/                 |          |
# |    fps                | 508      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 281000   |
# | train/                |          |
# |    entropy_loss       | -0.045   |
# |    explained_variance | 0.809    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 56199    |
# |    policy_loss        | 0.00769  |
# |    value_loss         | 4.62     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 835      |
# |    ep_rew_mean        | -19.6    |
# | time/                 |          |
# |    fps                | 501      |
# |    iterations         | 300      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 281500   |
# | train/                |          |
# |    entropy_loss       | -0.323   |
# |    explained_variance | 0.574    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 56299    |
# |    policy_loss        | -0.753   |
# |    value_loss         | 0.887    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 844      |
# |    ep_rew_mean        | -20.5    |
# | time/                 |          |
# |    fps                | 497      |
# |    iterations         | 400      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 282000   |
# | train/                |          |
# |    entropy_loss       | -0.331   |
# |    explained_variance | -3.54    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 56399    |
# |    policy_loss        | 0.376    |
# |    value_loss         | 2.84     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 844      |
# |    ep_rew_mean        | -20.5    |
# | time/                 |          |
# |    fps                | 494      |
# |    iterations         | 500      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 282500   |
# | train/                |          |
# |    entropy_loss       | -0.277   |
# |    explained_variance | -0.692   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 56499    |
# |    policy_loss        | -0.153   |
# |    value_loss         | 2.29     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 852      |
# |    ep_rew_mean        | -20.6    |
# | time/                 |          |
# |    fps                | 493      |
# |    iterations         | 600      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 283000   |
# | train/                |          |
# |    entropy_loss       | -0.155   |
# |    explained_variance | 0.301    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 56599    |
# |    policy_loss        | 0.0565   |
# |    value_loss         | 11.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 852      |
# |    ep_rew_mean        | -20.6    |
# | time/                 |          |
# |    fps                | 492      |
# |    iterations         | 700      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 283500   |
# | train/                |          |
# |    entropy_loss       | -0.456   |
# |    explained_variance | 0.723    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 56699    |
# |    policy_loss        | 0.388    |
# |    value_loss         | 0.155    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 861       |
# |    ep_rew_mean        | -21.3     |
# | time/                 |           |
# |    fps                | 491       |
# |    iterations         | 800       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 284000    |
# | train/                |           |
# |    entropy_loss       | -0.001    |
# |    explained_variance | 0.483     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 56799     |
# |    policy_loss        | -5.69e-05 |
# |    value_loss         | 7.89      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 861      |
# |    ep_rew_mean        | -21.3    |
# | time/                 |          |
# |    fps                | 487      |
# |    iterations         | 900      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 284500   |
# | train/                |          |
# |    entropy_loss       | -0.357   |
# |    explained_variance | 0.827    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 56899    |
# |    policy_loss        | -0.101   |
# |    value_loss         | 0.622    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 869      |
# |    ep_rew_mean        | -21.7    |
# | time/                 |          |
# |    fps                | 493      |
# |    iterations         | 1000     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 285000   |
# | train/                |          |
# |    entropy_loss       | -3.9e-09 |
# |    explained_variance | 0.583    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 56999    |
# |    policy_loss        | -0       |
# |    value_loss         | 7.72     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 869      |
# |    ep_rew_mean        | -21.7    |
# | time/                 |          |
# |    fps                | 496      |
# |    iterations         | 1100     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 285500   |
# | train/                |          |
# |    entropy_loss       | -0.394   |
# |    explained_variance | 0.78     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57099    |
# |    policy_loss        | -0.323   |
# |    value_loss         | 0.926    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 869      |
# |    ep_rew_mean        | -21.7    |
# | time/                 |          |
# |    fps                | 495      |
# |    iterations         | 1200     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 286000   |
# | train/                |          |
# |    entropy_loss       | -0.539   |
# |    explained_variance | 0.971    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57199    |
# |    policy_loss        | -0.219   |
# |    value_loss         | 0.0313   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 876      |
# |    ep_rew_mean        | -25.3    |
# | time/                 |          |
# |    fps                | 499      |
# |    iterations         | 1300     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 286500   |
# | train/                |          |
# |    entropy_loss       | -0.345   |
# |    explained_variance | 0.977    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57299    |
# |    policy_loss        | -0.0769  |
# |    value_loss         | 0.0968   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 876      |
# |    ep_rew_mean        | -25.3    |
# | time/                 |          |
# |    fps                | 501      |
# |    iterations         | 1400     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 287000   |
# | train/                |          |
# |    entropy_loss       | -0.421   |
# |    explained_variance | 0.664    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57399    |
# |    policy_loss        | -0.171   |
# |    value_loss         | 0.786    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 879      |
# |    ep_rew_mean        | -27.2    |
# | time/                 |          |
# |    fps                | 501      |
# |    iterations         | 1500     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 287500   |
# | train/                |          |
# |    entropy_loss       | -0.323   |
# |    explained_variance | 0.911    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57499    |
# |    policy_loss        | 0.348    |
# |    value_loss         | 1.18     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 879      |
# |    ep_rew_mean        | -27.2    |
# | time/                 |          |
# |    fps                | 505      |
# |    iterations         | 1600     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 288000   |
# | train/                |          |
# |    entropy_loss       | -0.4     |
# |    explained_variance | 0.918    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57599    |
# |    policy_loss        | 0.271    |
# |    value_loss         | 3.97     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 886      |
# |    ep_rew_mean        | -27.8    |
# | time/                 |          |
# |    fps                | 510      |
# |    iterations         | 1700     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 288500   |
# | train/                |          |
# |    entropy_loss       | -0.15    |
# |    explained_variance | 0.961    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57699    |
# |    policy_loss        | -0.022   |
# |    value_loss         | 0.513    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 886      |
# |    ep_rew_mean        | -27.8    |
# | time/                 |          |
# |    fps                | 514      |
# |    iterations         | 1800     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 289000   |
# | train/                |          |
# |    entropy_loss       | -0.138   |
# |    explained_variance | 0.33     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57799    |
# |    policy_loss        | 0.208    |
# |    value_loss         | 0.497    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 892      |
# |    ep_rew_mean        | -29.6    |
# | time/                 |          |
# |    fps                | 518      |
# |    iterations         | 1900     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 289500   |
# | train/                |          |
# |    entropy_loss       | -0.415   |
# |    explained_variance | 0.289    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57899    |
# |    policy_loss        | -0.83    |
# |    value_loss         | 9.93     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 892      |
# |    ep_rew_mean        | -29.6    |
# | time/                 |          |
# |    fps                | 521      |
# |    iterations         | 2000     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 290000   |
# | train/                |          |
# |    entropy_loss       | -0.379   |
# |    explained_variance | 0.552    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57999    |
# |    policy_loss        | -0.469   |
# |    value_loss         | 1.2      |
# ------------------------------------

# %%
from stable_baselines3 import DQN

# %%
# Create directories for saving models and logs if they don't exist
models_dir = 'models/DQN'
logdir = 'logs'

# Create the models directory if it doesn't exist
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

# Create the logs directory if it doesn't exist
if not os.path.exists(logdir):
    os.makedirs(logdir)

# %%
model = DQN('MlpPolicy', env, verbose=1,tensorboard_log=logdir)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
TIMESTEPS = 10000
for i in range (1,30):
    model.learn(total_timesteps=TIMESTEPS,reset_num_timesteps=False, tb_log_name='DQN')
    model.save(f"{models_dir}/{TIMESTEPS*i}")
# Out:
# Logging to logs\DQN_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 10767    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 431      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.8     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.25     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 11117    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 790      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.8     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 11394    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1186     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.7     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 11377    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1531     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -204     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 11604    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2003     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.4     |
# |    ep_rew_mean      | -203     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 11598    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2385     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.2     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 11632    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2695     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 11628    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3055     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 11625    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3345     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 11633    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3720     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 11613    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4004     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 11629    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4359     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 11638    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4700     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 11676    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5101     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 11670    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5414     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.1     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 11664    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5703     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.4     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 11663    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6076     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 11653    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6421     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 11661    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7709     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 11660    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8105     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 11672    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8429     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 11685    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8836     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 11663    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9216     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 11674    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9622     |
# ----------------------------------
# Logging to logs\DQN_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 2102     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10006    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.7     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 11065    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10397    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.4     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 11263    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10731    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.3     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 11533    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11118    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.5     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 11680    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11483    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.5     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 11637    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11757    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.7     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 11653    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12156    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.4     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 11670    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12533    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.3     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 11698    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12984    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 11722    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13389    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 11785    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13832    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 11798    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 14214    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 11742    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 14570    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 11721    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 14914    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 11724    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 15279    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -156     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 11743    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 15699    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 11754    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 11786    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16593    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 11777    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16918    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 11777    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 17248    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.3     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 11764    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 17640    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96       |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 11780    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 18028    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.3     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 11762    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 18369    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.2     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 11762    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 18734    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.3     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 11772    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 19154    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 11775    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 19498    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 11769    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 19846    |
# ----------------------------------
# Logging to logs\DQN_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 9990     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 20200    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 11193    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 20605    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 11358    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 20955    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 11275    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 21264    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 11194    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 21591    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 11235    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 22013    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 11348    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 22408    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.4     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 11395    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 22726    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 11451    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 23129    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 11502    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 23500    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 11597    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 23970    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 11571    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 24297    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 11606    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 24647    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 11634    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 25019    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 11655    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 25413    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 11655    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 25728    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 11669    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 26062    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 11701    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 26512    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 11725    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 26948    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 11735    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 27306    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -205     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 11743    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 27687    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 11732    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 28044    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -202     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 11751    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 28445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 11740    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 28743    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -202     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 11750    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 29127    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | -206     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 11744    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 29616    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -208     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 11752    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 29952    |
# ----------------------------------
# Logging to logs\DQN_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -208     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 10081    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 30333    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | -211     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 11034    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 30751    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | -213     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 11159    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 31098    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -208     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 11224    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 31410    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -209     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 11380    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 31817    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95       |
# |    ep_rew_mean      | -212     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 11518    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 32231    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.4     |
# |    ep_rew_mean      | -211     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 11423    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 32567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | -210     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 11428    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 32980    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -206     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 11490    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 33295    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.9     |
# |    ep_rew_mean      | -208     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 11499    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 33689    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -210     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 11518    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 34018    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -208     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 11554    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 34331    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -212     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 11537    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 34683    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -211     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 11574    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 35080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -205     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 11556    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 35350    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -206     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 11562    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 35700    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 11587    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 36083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 11594    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 36400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 11594    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 36783    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 11642    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 37254    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 11625    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 37581    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 11639    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 37986    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 11637    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 38334    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 11641    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 38687    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 11644    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 39097    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 11638    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 39442    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 11624    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 39721    |
# ----------------------------------
# Logging to logs\DQN_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 7493     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 40075    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 10704    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 40450    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.4     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 10932    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 40755    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 11199    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 41177    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.3     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 11353    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 41500    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.4     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 11326    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 41916    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 11394    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 42338    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 11453    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 42717    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 11457    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 43039    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 11509    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 43410    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 11525    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 43807    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 11506    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 44100    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 11557    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 44477    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 11546    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 44831    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 11563    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 45139    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 11555    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 45517    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 11577    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 45852    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.1     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 11605    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 46168    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.3     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 11591    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 46509    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -168     |
# ...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 640      |
# |    ep_rew_mean      | -131     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 933      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 133697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.727    |
# |    n_updates        | 20924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 660      |
# |    ep_rew_mean      | -124     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 928      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 137697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.618    |
# |    n_updates        | 21924    |
# ----------------------------------
# Logging to logs\DQN_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 686      |
# |    ep_rew_mean      | -119     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 932      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 141697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.562    |
# |    n_updates        | 22924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 711      |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 927      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 145697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.307    |
# |    n_updates        | 23924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 745      |
# |    ep_rew_mean      | -113     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 933      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 149697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.75     |
# |    n_updates        | 24924    |
# ----------------------------------
# Logging to logs\DQN_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 778      |
# |    ep_rew_mean      | -110     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 952      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 153697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.03     |
# |    n_updates        | 25924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 803      |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 941      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 157697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.576    |
# |    n_updates        | 26924    |
# ----------------------------------
# Logging to logs\DQN_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 820      |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 944      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 161697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.567    |
# |    n_updates        | 27924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 844      |
# |    ep_rew_mean      | -104     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 930      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 165697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.448    |
# |    n_updates        | 28924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 851      |
# |    ep_rew_mean      | -105     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 939      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 169697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.835    |
# |    n_updates        | 29924    |
# ----------------------------------
# Logging to logs\DQN_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 883      |
# |    ep_rew_mean      | -102     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 936      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 173697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.513    |
# |    n_updates        | 30924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 909      |
# |    ep_rew_mean      | -103     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 932      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 177697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.3      |
# |    n_updates        | 31924    |
# ----------------------------------
# Logging to logs\DQN_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 931      |
# |    ep_rew_mean      | -103     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 926      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 181697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.3      |
# |    n_updates        | 32924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 946      |
# |    ep_rew_mean      | -103     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 920      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 185697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.995    |
# |    n_updates        | 33924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 954      |
# |    ep_rew_mean      | -103     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 932      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 189697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.632    |
# |    n_updates        | 34924    |
# ----------------------------------
# Logging to logs\DQN_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 976      |
# |    ep_rew_mean      | -103     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 975      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 193697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.527    |
# |    n_updates        | 35924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 981      |
# |    ep_rew_mean      | -103     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 959      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 197697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.21     |
# |    n_updates        | 36924    |
# ----------------------------------
# Logging to logs\DQN_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 984      |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 874      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 201697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.19     |
# |    n_updates        | 37924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 993      |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 933      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 205549   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.344    |
# |    n_updates        | 38887    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 993      |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 936      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 209549   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.709    |
# |    n_updates        | 39887    |
# ----------------------------------
# Logging to logs\DQN_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 993      |
# |    ep_rew_mean      | -110     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 924      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 213549   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.612    |
# |    n_updates        | 40887    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | -112     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 943      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 217549   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.543    |
# |    n_updates        | 41887    |
# ----------------------------------
# Logging to logs\DQN_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | -114     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 952      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 221549   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.455    |
# |    n_updates        | 42887    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | -114     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 945      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 225549   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.463    |
# |    n_updates        | 43887    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 993      |
# |    ep_rew_mean      | -114     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 942      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 229019   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.377    |
# |    n_updates        | 44754    |
# ----------------------------------
# Logging to logs\DQN_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 993      |
# |    ep_rew_mean      | -115     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 934      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 233019   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.718    |
# |    n_updates        | 45754    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 989      |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 934      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 236578   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.534    |
# |    n_updates        | 46644    |
# ----------------------------------
# Logging to logs\DQN_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 986      |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 918      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 240264   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.669    |
# |    n_updates        | 47565    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 982      |
# |    ep_rew_mean      | -120     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 934      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 243874   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.507    |
# |    n_updates        | 48468    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 982      |
# |    ep_rew_mean      | -120     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 933      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 247874   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.64     |
# |    n_updates        | 49468    |
# ----------------------------------

# %% [markdown]
# # Understanding the output
#
# Sample:
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -283     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 879      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 52787    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.35     |
# |    n_updates     | 696     |
# ----------------------------------
#
#
# let's break down each of the output parameters from this sample training log, which is often seen when training reinforcement learning models using libraries like Stable Baselines or OpenAI Gym.
#
# ### Rollout Parameters
#
# - **`ep_len_mean` (Mean Episode Length)**: This is the average length of episodes over a certain period. A value of 101 suggests that, on average, episodes last for 101 timesteps. This can be an indicator of how long the agent is able to "survive" or maintain a certain level of performance in the environment.
#
# - **`ep_rew_mean` (Mean Episode Reward)**: This is the average reward obtained per episode over a certain period. A value of -283 suggests that the agent is, on average, receiving a negative reward, which usually indicates poor performance.
#
# - **`exploration_rate`**: This is the rate at which the agent explores the environment, usually governed by an ε-greedy strategy or similar. A value of 0.05 means that 5% of the time, the agent takes a random action to explore the state space.
#
# ### Time Parameters
#
# - **`episodes`**: This indicates the total number of episodes that have been completed. A value of 552 suggests that the agent has completed 552 episodes.
#
# - **`fps` (Frames Per Second)**: This is the speed of the simulation, indicating how many timesteps the model can process per second. A value of 879 means the model is processing 879 timesteps per second.
#
# - **`time_elapsed`**: This is the total time elapsed in seconds since the training started. A value of 3 suggests that the training has been running for 3 seconds.
#
# - **`total_timesteps`**: This indicates the total number of timesteps that have been processed so far. A value of 52,787 means the agent has interacted with the environment for that many timesteps.
#
# ### Training Parameters
#
# - **`learning_rate`**: This is the learning rate used in the optimization algorithm. A value of 0.0001 is fairly typical for many RL problems.
#
# - **`loss`**: This is the value of the loss function, which the optimization algorithm is trying to minimize. A value of 1.35 suggests the current "error" or "loss" in the model's predictions.
#
# - **`n_updates`**: This indicates the number of times the model's parameters have been updated. A value of 696 suggests that 696 updates have been made.
#
# Each of these metrics provides valuable insights into the training process, helping you understand the agent's performance, the efficiency of the training, and the stability of the learning.

# %%
from IPython.display import Image
Image(filename="tensorboard_pic.JPG")

# %% [markdown]
# The command `tensorboard --logdir=logs` is used to launch TensorBoard, a visualization tool for machine learning experiments, and point it to the directory where the log files are stored. In this case, the log files are expected to be in a directory named `logs`. Once TensorBoard is running, it will continuously monitor the `logs` directory for any updates and reflect those changes in its visualizations. This is particularly useful for tracking metrics, visualizing model architectures, and monitoring training progress in real-time. By setting up TensorBoard in this manner, you can gain valuable insights into the behavior and performance of your reinforcement learning models, making it easier to debug issues, optimize hyperparameters, and understand the learning dynamics.

# %% [markdown]
# !pip install tensorflow to install tensorboard #see https://stackoverflow.com/questions/33634008/how-do-i-install-tensorflows-tensorboard/33634101#33634101

# %% [markdown]
# tensorboard --logdir=logs
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.13.0 at http://localhost:6006/ (Press CTRL+C to quit)
